# %%
import pandas as pd

# %%
data = pd.read_csv('../data/train.csv')

# %% [markdown]
# Dataset Description
# The dataset for this competition (both train and test) was generated from a deep learning model trained on the Gemstone Price Prediction dataset. Feature distributions are close to, but not exactly the same, as the original. Feel free to use the original dataset as part of this competition, both to explore differences as well as to see whether incorporating the original in training improves model performance.
#
# Files
# train.csv - the training dataset; price is the target
# test.csv - the test dataset; your objective is to predict price
# sample_submission.csv - a sample submission file in the correct format

# %%
data.head(20)
# Out:
#     id  carat        cut color clarity  depth  table     x     y     z  price
# 0    0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1    1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2    2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3    3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4    4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# 5    5   1.51  Very Good     J     SI1   62.8   58.0  7.34  7.29  4.59   7506
# 6    6   0.74      Ideal     E     VS2   61.8   57.0  5.76  5.79  3.57   3229
# 7    7   1.34    Premium     G     SI2   62.5   57.0  7.00  7.05  4.38   6224
# 8    8   0.30      Ideal     F      IF   62.0   56.0  4.35  4.37  2.70    886
# 9    9   0.30       Good     J     VS1   63.6   57.0  4.26  4.28  2.72    421
# 10  10   1.01  Very Good     G     VS2   63.1   57.0  6.40  6.34  4.03   5914
# ...

# %%
data.shape # size of the data (how much memory it will occupy)
# Out:
# (193573, 11)

# %%
data.isnull() #Find null value in data , there is no null data
# Out:
#            id  carat    cut  color  clarity  depth  table      x      y  \
# 0       False  False  False  False    False  False  False  False  False
# 1       False  False  False  False    False  False  False  False  False
# 2       False  False  False  False    False  False  False  False  False
# 3       False  False  False  False    False  False  False  False  False
# 4       False  False  False  False    False  False  False  False  False
# ...       ...    ...    ...    ...      ...    ...    ...    ...    ...
# 193568  False  False  False  False    False  False  False  False  False
# 193569  False  False  False  False    False  False  False  False  False
# 193570  False  False  False  False    False  False  False  False  False
# 193571  False  False  False  False    False  False  False  False  False
# 193572  False  False  False  False    False  False  False  False  False
#
#             z  price
# 0       False  False
# 1       False  False
# 2       False  False
# ...

# %%
data.info() # It is info of all the datatypes of the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data.columns # will get all the cols of data
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
#data.drop(labels=['id'],axis=1) 
# here we are dropping id because it is not required uit is just a unique id, it doesn't define any pattern in data.
#data 
# here you are seeing that we are still getting id after dropping it becaue we are not changed to original data ,
#  so to change in original data we have to use another attribute
#  INPLACE = TRUE. Let's see.

data.drop(labels=['id'],axis=1,inplace=True)
data# here will you not see the ID col.
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
data
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# ...

# %%
# redundancy = duplicate in row
data.duplicated() # will give all the duplicate rows

print(data.duplicated().sum()) # will do sum of all the true (duplicate) rows.
# Out:
# 0

# %% [markdown]
# # Categorize or Seggeragate the data

# %%
data.dtypes # here we have different dtypes. so to categorize them in same datat types we have to write this code:
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
cat_cols = data.columns[data.dtypes=='object'] # this is the cols which have object dtypes.

# %%
data[cat_cols] # here we have categorize the data of Object datatype.
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
# Similarly we do for other data type
num_cols = data.columns[data.dtypes!='object']

# %%
data[num_cols]
# Out:
#         carat  depth  table     x     y     z  price
# 0        1.52   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...    ...    ...   ...   ...   ...    ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 7 columns]

# %%
data[num_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   carat   193573 non-null  float64
#  1   depth   193573 non-null  float64
#  2   table   193573 non-null  float64
#  3   x       193573 non-null  float64
#  4   y       193573 non-null  float64
#  5   z       193573 non-null  float64
#  6   price   193573 non-null  int64
# dtypes: float64(6), int64(1)
# memory usage: 10.3 MB
